# %% [markdown]
# <a href="https://colab.research.google.com/github/Mallika225-28/CODSOFT-Projects/blob/main/Task5_CODSOFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***TASK-5: CREDIT CARD FRAUD DETECTION***
# * Author : Mallika Santra
# * Batch :  MAY BATCH B28
# * Domain : Data Science
# * Aims : To build a machine learning model to identify fraudulent credit card
# transactions.

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_curve,f1_score,precision_recall_curve, precision_score, recall_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.shape
# Out:
# (211990, 31)

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 211985  138661.0  0.126593  1.091750 -1.090496  0.029851  0.211015 -1.389972
# 211986  138662.0  2.019604  0.016811 -1.631122  0.358207  0.261196 -0.696347
# 211987  138663.0 -0.980098  0.193904  0.467762 -1.136218  1.802785 -0.899924
# 211988  138663.0 -0.045674  0.094610  1.067176 -0.663305 -0.537060 -0.482020
# 211989  138664.0 -0.154159 -0.169538  0.104102  0.801081  1.127058  1.496279
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 211985  0.777739  0.060607 -0.254675  ...  0.354405  0.970889  0.005842
# 211986 -0.007064 -0.023775  0.428041  ... -0.316812 -0.908902  0.367657
# 211987  0.929753 -0.441782  0.179331  ... -0.359459 -0.846367 -0.372509
# 211988  0.413272  0.006145  0.845524  ...  0.295790  0.889576  0.055431
# 211989 -0.272910  0.517337  0.183614  ...       NaN       NaN       NaN
#
# ...

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211990 entries, 0 to 211989
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    211990 non-null  float64
#  1   V1      211990 non-null  float64
#  2   V2      211990 non-null  float64
#  3   V3      211990 non-null  float64
#  4   V4      211990 non-null  float64
#  5   V5      211990 non-null  float64
#  6   V6      211990 non-null  float64
#  7   V7      211990 non-null  float64
#  8   V8      211990 non-null  float64
#  9   V9      211990 non-null  float64
#  10  V10     211989 non-null  float64
#  11  V11     211989 non-null  float64
#  12  V12     211989 non-null  float64
#  13  V13     211989 non-null  float64
#  14  V14     211989 non-null  float64
#  15  V15     211989 non-null  float64
#  16  V16     211989 non-null  float64
#  17  V17     211989 non-null  float64
#  18  V18     211989 non-null  float64
#  19  V19     211989 non-null  float64
# ...

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data.dropna(inplace=True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 211989 entries, 0 to 211988
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    211989 non-null  float64
#  1   V1      211989 non-null  float64
#  2   V2      211989 non-null  float64
#  3   V3      211989 non-null  float64
#  4   V4      211989 non-null  float64
#  5   V5      211989 non-null  float64
#  6   V6      211989 non-null  float64
#  7   V7      211989 non-null  float64
#  8   V8      211989 non-null  float64
#  9   V9      211989 non-null  float64
#  10  V10     211989 non-null  float64
#  11  V11     211989 non-null  float64
#  12  V12     211989 non-null  float64
#  13  V13     211989 non-null  float64
#  14  V14     211989 non-null  float64
#  15  V15     211989 non-null  float64
#  16  V16     211989 non-null  float64
#  17  V17     211989 non-null  float64
#  18  V18     211989 non-null  float64
#  19  V19     211989 non-null  float64
# ...

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    211595
# 1.0       394
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unblanced

# %% [markdown]
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (211595, 31)
# (394, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    211595.000000
# mean         90.042226
# std         248.388744
# min           0.000000
# 25%           6.000000
# 50%          23.080000
# 75%          79.600000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     394.000000
# mean      123.172970
# std       256.841767
# min         0.000000
# 25%         1.000000
# 50%        13.385000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    74359.763841 -0.072238 -0.011782  0.270715  0.051800 -0.080088
# 1.0    62970.449239 -5.564086  4.145138 -7.653811  4.735781 -4.009483
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.042957 -0.026117  0.009499  0.011594  ...  0.014673 -0.012361
# 1.0   -1.393320 -6.501846  0.664570 -2.742972  ...  0.394589  0.778108
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.035611 -0.013333  0.002860  0.049997  0.004210  0.000488  0.001359
# 1.0   -0.012420 -0.048604 -0.067137  0.065962  0.038256  0.182273  0.060390
#
#            Amount
# Class
# 0.0     90.042226
# 1.0    123.172970
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 112501   72676.0 -0.752202  1.010452  1.515108 -0.186846 -0.062884 -0.288689
# 100374   67495.0 -0.750453 -0.370205  3.174389 -1.418881 -1.169681  0.663006
# 198643  132586.0  1.634157 -0.637046 -1.962267  0.224493  0.597293  0.759635
# 32005    36601.0  1.092339 -0.063143  1.345504  2.738232 -0.768844  0.857445
# 152714   97446.0  1.974137 -0.414604  0.214343  0.541026 -0.947125 -0.378968
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 112501  0.400757  0.295412 -0.274008  ... -0.182694 -0.464169  0.039439
# 100374 -0.615121  0.333891  0.435962  ...  0.112213  0.844567 -0.376960
# 198643 -0.185146  0.388910  1.006240  ... -0.076663 -0.221469  0.135296
# 32005  -0.842873  0.476848  0.501090  ...  0.029682  0.323601 -0.159378
# 152714 -0.955185 -0.064110  2.643697  ... -0.119637  0.059012  0.304962
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 203700  134928.0  1.204934  3.238070 -6.010324  5.720847  1.548400 -2.321064
# 204064  135095.0  0.232512  0.938944 -4.647780  3.079844 -1.902655 -1.041408
# 204079  135102.0  1.862102 -0.124052 -1.989752  0.382609  0.473032 -0.674517
# 204503  135314.0 -3.158990  1.765452 -3.390168  0.987410 -1.509930 -1.280952
# 208651  137211.0  0.630579  1.183631 -5.066283  2.179903 -0.703376 -0.103614
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 203700 -0.781880  0.076619 -2.976249  ...  0.098341 -0.845866 -0.031228
# 204064 -1.020407  0.547069 -1.105990  ...  0.911373  1.042929  0.999394
# 204079  0.298621 -0.282416  0.802053  ... -0.204158 -0.511441  0.077874
# 204503 -2.719557  0.718325 -1.660183  ...  1.120533  1.605085 -0.618637
# 208651 -3.490350  1.094734 -0.717418  ...  0.621622  0.043807  0.102711
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    394
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    73990.272358  0.077615 -0.111577  0.348031  0.043145 -0.115463
# 1.0    62970.449239 -5.564086  4.145138 -7.653811  4.735781 -4.009483
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0   -0.010439 -0.114406  0.073886  0.113088  ...  0.026929 -0.017507
# 1.0   -1.393320 -6.501846  0.664570 -2.742972  ...  0.394589  0.778108
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.048186  0.005204  0.016211  0.045488  0.003515 -0.013477 -0.014157
# 1.0   -0.012420 -0.048604 -0.067137  0.065962  0.038256  0.182273  0.060390
#
#           Amount
# Class
# 0.0     81.30313
# 1.0    123.17297
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 112501   72676.0 -0.752202  1.010452  1.515108 -0.186846 -0.062884 -0.288689
# 100374   67495.0 -0.750453 -0.370205  3.174389 -1.418881 -1.169681  0.663006
# 198643  132586.0  1.634157 -0.637046 -1.962267  0.224493  0.597293  0.759635
# 32005    36601.0  1.092339 -0.063143  1.345504  2.738232 -0.768844  0.857445
# 152714   97446.0  1.974137 -0.414604  0.214343  0.541026 -0.947125 -0.378968
# ...          ...       ...       ...       ...       ...       ...       ...
# 203700  134928.0  1.204934  3.238070 -6.010324  5.720847  1.548400 -2.321064
# 204064  135095.0  0.232512  0.938944 -4.647780  3.079844 -1.902655 -1.041408
# 204079  135102.0  1.862102 -0.124052 -1.989752  0.382609  0.473032 -0.674517
# 204503  135314.0 -3.158990  1.765452 -3.390168  0.987410 -1.509930 -1.280952
# 208651  137211.0  0.630579  1.183631 -5.066283  2.179903 -0.703376 -0.103614
#
# ...

# %%
print(Y)
# Out:
# 112501    0.0
# 100374    0.0
# 198643    0.0
# 32005     0.0
# 152714    0.0
#          ...
# 203700    1.0
# 204064    1.0
# 204079    1.0
# 204503    1.0
# 208651    1.0
# Name: Class, Length: 886, dtype: float64

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (886, 30) (708, 30) (178, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9576271186440678

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9438202247191011

# %%
print("F1 Score:", f1_score(Y_test, X_test_prediction))
precision = precision_score(Y_test, X_test_prediction)
recall = recall_score(Y_test, X_test_prediction)
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print("Confusion Matrix:\n", confusion_matrix(Y_test, X_test_prediction))
print("Classification Report:\n", classification_report(Y_test, X_test_prediction))
# Out:
# F1 Score: 0.9333333333333333
# Precision : 0.9859
# Recall    : 0.8861
# Confusion Matrix:
#  [[98  1]
#  [ 9 70]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.92      0.99      0.95        99
#          1.0       0.99      0.89      0.93        79
#
#     accuracy                           0.94       178
#    macro avg       0.95      0.94      0.94       178
# weighted avg       0.95      0.94      0.94       178
